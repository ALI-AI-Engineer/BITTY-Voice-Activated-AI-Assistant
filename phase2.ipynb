# %% [markdown]
#                         Phase 2 of Project

# %% [markdown]
# This Block Lets the text to speak

# %%
import pyttsx3

def speak(text):
    engine = pyttsx3.init()
    engine.say(text)
    engine.runAndWait()
    engine.stop()

# %% [markdown]
# This Block Lets you open a website

# %%
import webbrowser

def open_website(query):
    if "open google " in query.lower():
        speak("Google is opened")
        webbrowser.open("https://google.com")

    elif "open facebook" in query.lower():
        speak("Facebook is opened")
        webbrowser.open("https://facebook.com")

    elif "open youtube" in query.lower():
        speak("YouTube is opened")
        webbrowser.open("https://youtube.com")

    elif "open linkedin" in query.lower():
        speak("Linkedin is opened")
        webbrowser.open("https://linkedin.com")

# %% [markdown]
# This Block Lets you play music

# %%
import music_names
import webbrowser

def play_music(song):
    link = music_names.music[song]
    webbrowser.open(link)

# %% [markdown]
# This block lets you enter voice command and Act after listening wake word

# %%
import speech_recognition as sr

# Initialize TTS engine once
engine = pyttsx3.init()

def listen_for_wake_word(wake_word="alexa"):
    recognizer = sr.Recognizer()
    mic = sr.Microphone()

    with mic as source:
        recognizer.adjust_for_ambient_noise(source)
        print(f"Listening for wake word '{wake_word}'...")

        while True:
            try:
                # Listen for speech
                # print("Say Something....")
                audio = recognizer.listen(source, timeout=5, phrase_time_limit=5)
                text = recognizer.recognize_google(audio).lower()
                print("Heard:", text)

                if "website" in text.lower():
                    open_website(text)

                elif "play" in text.lower():
                    song = text.lower().split(" ")[1]
                    print(song, type(song))
                    play_music(song)

                # Check for wake word
                elif wake_word in text.lower():
                    speak("Yes? What can I do for you today?")
                    # Here you can call another function for commands after wake word
                    print("Wake word detected! Ready for command.")
                
                #Exits the loop and stops execution
                elif "exit" in text.lower():
                    speak("Exiting the Program, GoodBye")
                    break
                
                
                    
                    

            except sr.UnknownValueError:
                print("Could not understand audio")
                break

            except sr.RequestError:
                print("Could not request results; check your internet connection.")
                break

            except sr.WaitTimeoutError:
                print("No speech detected within timeout, just continue listening")
                break

# %% [markdown]
# This __name__ thing lets you run code only if its executed in main file

# %%
if __name__ == "__main__":
    listen_for_wake_word("alexa")
# Out:
# Listening for wake word 'alexa'...
# Heard: play a song
# a <class 'str'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 if __name__ == "__main__":
# ----> 2     listen_for_wake_word("alexa")
#
# Cell In[17], line 28, in listen_for_wake_word(wake_word)
#      26     song = text.lower().split(" ")[1]
#      27     print(song, type(song))
# ---> 28     play_music(song)
#      30 # Check for wake word
#      31 elif wake_word in text.lower():
#
# Cell In[16], line 5, in play_music(song)
#       4 def play_music(song):
# ----> 5     link = music_names.music[song]
#       6     webbrowser.open(link)
#
# KeyError: 'a'
